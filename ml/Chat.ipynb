# %%
import json

from deeppavlov.deep import find_config, install_from_config, deep_download
from deeppavlov.core.commands.train import train_evaluate_model_from_config
from deeppavlov.core.commands.infer import build_model_from_config
import deeppavlov.models.tokenizers.nltk_tokenizer
# Out:
# email-validator not installed, email fields will be treated as str.
# To install, run: pip install email-validator
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-ca7bd99a68f6> in <module>
#       3 from deeppavlov.deep import find_config, install_from_config, deep_download
#       4 from deeppavlov.core.commands.train import train_evaluate_model_from_config
# ----> 5 from deeppavlov.core.commands.infer import build_model_from_config
#       6 import deeppavlov.models.tokenizers.nltk_tokenizer
#
# ImportError: cannot import name 'build_model_from_config'

# %%
from deeppavlov.contrib.skills.similarity_matching_skill import SimilarityMatchingSkill

# %%
rows = [
    ('Вы пришли к подопечному, поздравить его с Днем Рождения. Все прошло хорошо, и вы остались на подольше. Дети разоткровенничались и в ходе беседы ваш подопечный 14-и лет признается вам на ушко, что он сегодня украл телефон из магазина. Якобы сделал себе подарок на Др. Ваши действия?',
    '''Если ребенок доверил вам какой-то секрет, ваша задача его хранить и не выдавать. Если информация, которую вам доверили, кажется вам странной, опасной, противозаконной и требующей каких-то действий, то нужно действовать по следующему алгоритму: - предложить ребенку уединиться и поговорить на эту тему
- в ходе разговора постараться понять не обманывает ли он вас: задать уточняющие вопросы – где, когда и как произошла кража. Спросить у ребенка (спокойно мягко) зачем он украл вещь, есть ли в ней необходимость. Сказать, что какая классная бы и необходимая эта вещь ни была, воровство – это не лучший способ ее заполучить. Спросить у него, знает ли он, какие есть другие способы законные (накопить из детских денег, заработать, спросить может у кого-то из волонтеров есть б/у телефон и кто-то может ему одолжить, попросить на Новый год). Если ребенок идет на контакт, предложить ему вернуть эту вещь – самому или вместе с вами. Важно, уверить ребенка, что это в любом случае останется между вами.
- если в ходе разговора, вы понимаете, что ребенок врёт и он ничего не крал, нужно сказать ему об этом мягко: «Никита, мне кажется, ты лукавишь и на самом деле ничего не воровал». Можете спросить у него, зачем он так сказал? Обязательно сказать «как я рада, что ты ничего не крал!». Важно, не ругать ребенка за вранье, а попытаться понять его мотив. Скорее всего, ребенку не хватает внимания и таким образом он попытался его получить. Вы можете спросить у ребенка, может он хочет рассказать вам что-то другое. Уделите ему время один на один, скажите, что всегда готовы с ним просто поговорить.
- если ребенок отказался с вами обсуждать эту тему или закрылся во время обсуждения, скажите ему, что это останется между вами в любом случае, и что он всегда может это с вами обсудить даже через какое-то время. Важно: не доносить и не ябедничать воспитателюJ Это не принесет ничего, кроме отрицательного результата – воспитатель наругается на ребенка, ребенок поймет, что вы проболтались и перестанет с вами общаться (по крайней мере на какое-то время). А вещь так и останется у него)
Воровство в Детском доме – обычное явление. Мы как Наставники глобально с этим ничего не сделаем, т.к. дети живут в режиме дефицита личных вещей и перенимают друг у друга антисоциальное поведение. Это не значит, что нужно игнорировать эту тему и не замечать, что это есть. Важно высказывать свое мнение по этому поводу, говорить, что вы за них переживаете и что за это можно сесть в тюрьму и испортить себе жизнь. Обсуждать с детьми другие способы приобретения вещей.'''),
Может случиться так, что ребенок не пойдет на контакт в эту встречу и не выйдет из своей комнаты, пока вы не уйдете, потому что ему будет очень стыдно. Важно, обсудить с ним эту тему в следующий раз (можно начать с вопроса «Удалось ли ему помириться с воспитателем после той ссоры?») и все равно проговорить свои эмоции на эту тему и сказать, что вы его не осуждаете. Ребенок услышит, что вы помните о его ситуации, значит это для вас важно. И, возможно, если ситуация повториться, то ему будет проще сразу ее с вами обсудить.'''
    ),
    ('Разговаривать отказалась, трубку взял кто-то другой, я слышала ответы ребенка. Я не очень понимаю, что делать, и кто виноват.',
     '''Ситуация напряженная, однако Вы все делаете верно. И спасибо большое, что сохраняете спокойствие. Пока ребенку, видимо, лучше не звонить, если она не готова разговаривать лично.'''
    ),
    ('не загружается отчет, что делать?',
    '''Не переживайте, мы проверим, отправился ли ваш отчет. В списке отчетов можно посмотреть, что отчет был составлен, если его у нас не окажется - можно будет переотправить заново из приложения'''
    ),
]
import pandas as pd

# %%
df = pd.DataFrame(rows, columns=['Question', 'Answer'])
df.to_csv('faq_psycho.csv', index=False)

# %%
faq = SimilarityMatchingSkill(data_path = 'faq_psycho.csv',
                              x_col_name = 'Question', 
                              y_col_name = 'Answer',
                              save_load_path = './model',
                              config_type = 'tfidf_autofaq',
                              edit_dict = {},
                              train = True)
# ml/faq_dataset.csv
# Out:
# 2019-09-28 19:32:39.651 INFO in 'deeppavlov.core.data.utils'['utils'] at line 64: Downloading from http://files.deeppavlov.ai/vectorizer/tfidf_vectorizer_ruwiki.pkl to /Users/olegpro/solarcity/ml/model/vectorizer/tfidf_vectorizer_ruwiki.pkl
# 100%|██████████| 140M/140M [07:59<00:00, 293kB/s]
# 2019-09-28 19:40:39.181 INFO in 'deeppavlov.core.data.utils'['utils'] at line 64: Downloading from http://files.deeppavlov.ai/faq/school/tfidf_cos_sim_classifier.pkl to /Users/olegpro/solarcity/ml/model/faq/tfidf_cos_sim_classifier.pkl
# 100%|██████████| 12.0k/12.0k [00:00<00:00, 6.72MB/s]
# 2019-09-28 19:40:39.261 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 202: Loading model sklearn.feature_extraction.text:TfidfVectorizer from /Users/olegpro/solarcity/ml/model/vectorizer/tfidf_vectorizer_ruwiki.pkl
# ...

# %%
faq(['на ребенка орет злая тетка'],[],[])
# Out:
# (['Если ребенок доверил вам какой-то секрет, ваша задача его хранить и не выдавать. Если информация, которую вам доверили, кажется вам странной, опасной, противозаконной и требующей каких-то действий, то нужно действовать по следующему алгоритму: - предложить ребенку уединиться и поговорить на эту тему\n- в ходе разговора постараться понять не обманывает ли он вас: задать уточняющие вопросы – где, когда и как произошла кража. Спросить у ребенка (спокойно мягко) зачем он украл вещь, есть ли в ней необходимость. Сказать, что какая классная бы и необходимая эта вещь ни была, воровство – это не лучший способ ее заполучить. Спросить у него, знает ли он, какие есть другие способы законные (накопить из детских денег, заработать, спросить может у кого-то из волонтеров есть б/у телефон и кто-то может ему одолжить, попросить на Новый год). Если ребенок идет на контакт, предложить ему вернуть эту вещь – самому или вместе с вами. Важно, уверить ребенка, что это в любом случае останется между вам
#  [0.41])

# %%
faq(['вместо ребенка отвечает её подруга'],[],[])
# Out:
# (['В-первую очередь, вам нужно понять свое желание и оценить свои ресурсы: хотите ли вы побывать в психушке и навестить ребенка? Если нет, то по-честному ответить «Лиза, в больницу я к тебе не приеду, увидимся, когда вернешься в Детский дом».\nЕсли вы не против навестить девочку, и у вас это не вызывает страха или беспокойства, важно помнить, что сигареты/алкоголь/наркотики волонтерам передавать детям строго запрещено! Передавать Лизе фрукты и средства гигиены можно, но важно оценить свои денежные возможности и заранее её предупредить, что вы сможете купить, чтобы у нее не было неоправданных ожиданий, что ей сейчас принесут всего по три пакета. Поэтому ваш ответ может звучать так: «Лиза, я смогу навестить тебя тогда-то, принесу 1 кг яблок, 1 кг апельсинов, сигареты передавать запрещено»\nПеред походом обязательно нужно позвонить в больницу, уточнить время посещения (даже если ребенок вам написала свою версию и уверила, что «точно в любое время можно прийти»), уточнить, что можно прин
# ...

# %%
faq(['ребенка положили в психушку'],[],[])
# Out:
# (['В-первую очередь, вам нужно понять свое желание и оценить свои ресурсы: хотите ли вы побывать в психушке и навестить ребенка? Если нет, то по-честному ответить «Лиза, в больницу я к тебе не приеду, увидимся, когда вернешься в Детский дом».\nЕсли вы не против навестить девочку, и у вас это не вызывает страха или беспокойства, важно помнить, что сигареты/алкоголь/наркотики волонтерам передавать детям строго запрещено! Передавать Лизе фрукты и средства гигиены можно, но важно оценить свои денежные возможности и заранее её предупредить, что вы сможете купить, чтобы у нее не было неоправданных ожиданий, что ей сейчас принесут всего по три пакета. Поэтому ваш ответ может звучать так: «Лиза, я смогу навестить тебя тогда-то, принесу 1 кг яблок, 1 кг апельсинов, сигареты передавать запрещено»\nПеред походом обязательно нужно позвонить в больницу, уточнить время посещения (даже если ребенок вам написала свою версию и уверила, что «точно в любое время можно прийти»), уточнить, что можно прин
# ...

# %%
faq(['нажала "отправить отчет", боюсь, что отчет не отправился'],[],[])
# Out:
# (['Не переживайте, мы проверим, отправился ли ваш отчет. В списке отчетов можно посмотреть, что отчет был составлен, если его у нас не окажется - можно будет переотправить заново из приложения'],
#  [0.74])

# %%
predictions = faq(['нажала "отправить отчет", боюсь, что отчет не отправился'],[],[])
for text, prob in zip(*predictions):
    print(text, prob)
    if prob >= 0.7:
        print(text)
# Out:
# Не переживайте, мы проверим, отправился ли ваш отчет. В списке отчетов можно посмотреть, что отчет был составлен, если его у нас не окажется - можно будет переотправить заново из приложения 0.74
# Не переживайте, мы проверим, отправился ли ваш отчет. В списке отчетов можно посмотреть, что отчет был составлен, если его у нас не окажется - можно будет переотправить заново из приложения

# %%
predictions
# Out:
# (['Не переживайте, мы проверим, отправился ли ваш отчет. В списке отчетов можно посмотреть, что отчет был составлен, если его у нас не окажется - можно будет переотправить заново из приложения'],
#  [0.74])
